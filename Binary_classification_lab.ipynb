# %% [markdown]
# # Lab: SVMs on Extended MNIST
#
# In the demo for this unit, we saw how SVMs can be used for the classic problem of MNIST digit recognition. In this lab, we are going to extend the MNIST dataset by adding a number of non-digit letters and see if the classifier can distinguish the digits from the non-digits. All non-digits will be lumped as a single 11-th class. This is a highly simplified version of a 'detection' problem (as opposed to 'classification' problem). Detection is vital in OCR and related problems since the non useful characters must be rejected.
#
# In addition to the concepts in the demo, you will learn:
# * Combine multiple datasets
# * Select the SVM parameters (`C` and `gamma`) via cross-validation.
# * Use the `GridSearchCV` method to search for parameters with cross-validation.

# %% [markdown]
# As usual, we install the standard packages

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model, preprocessing

# %% [markdown]
# ## Downloading the EMNIST Dataset
#
# After creating the highly popular MNIST dataset, NIST created an extended version of the dataset that includes letters and digits.
# The extended datbase (called EMNIST) also has many more examples per class.
#
# To download the data, go to the [EMNIST webpage](https://www.nist.gov/itl/iad/image-group/emnist-dataset).  Near the bottom, you will see a link for `Binary format as the original MNIST dataset`.  If you click on this link, you will download a `gzip.zip` file with several datasets in it.  The total file is 562M, so it may take some time and diskspace to download.  Unzip this file to get a directory named `gzip`.  The only files that we'll use are the ones named `emnist-digits...` and `eminst-letters...`, so you can delete the other files if you want to save disk space.  Make a note of where this `gzip` directory is in your workspace.

# %%
# TODO:  Download gzip/emnist-digits* and gzip/emnist-letters* to a known location

# %% [markdown]
# Since the EMNIST files have a somewhat complicated form, we'll install a helper package to extract them.

# %%
# %pip install python-mnist
from mnist import MNIST
# Out:
# Requirement already satisfied: python-mnist in /opt/anaconda3/lib/python3.12/site-packages (0.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next we'll tell the helper where our gzip file is located.

# %%
# TODO: Edit the file location below to point to your gzip directory
mndata = MNIST('/Users/evansmacbookair/Downloads/gzip/')

# %% [markdown]
# Now we'll load the data and convert it to numpy format.
# If you get a `FileNotFoundError`, this means that the file location you entered above does not contain the expected data.
# Look closely at the details in the error statement to debug the problem.

# %%
# load digits data... be patient; this takes a few moments
mndata.select_emnist('digits')
Xtr_dig, ytr_dig = mndata.load_training()
Xtr_dig = np.array(Xtr_dig)
ytr_dig = np.array(ytr_dig)
print('Xtr_dig.shape =',Xtr_dig.shape)
print('ytr_dig.shape =',ytr_dig.shape)
Xts_dig, yts_dig = mndata.load_testing()
Xts_dig = np.array(Xts_dig)
yts_dig = np.array(yts_dig)
print('Xts.shape =',Xts_dig.shape)
print('yts.shape =',yts_dig.shape)

# load letters data... be patient; this takes a few moments
mndata.select_emnist('letters')
Xtr_let, ytr_let = mndata.load_training()
Xtr_let = np.array(Xtr_let)
ytr_let = np.array(ytr_let)
print('Xtr_let.shape =',Xtr_let.shape)
print('ytr_let.shape =',ytr_let.shape)
Xts_let, yts_let = mndata.load_testing()
Xts_let = np.array(Xts_let)
yts_let = np.array(yts_let)
print('Xts_let.shape =',Xts_let.shape)
print('yts_let.shape =',yts_let.shape)
# Out:
# Xtr_dig.shape = (240000, 784)
# ytr_dig.shape = (240000,)
# Xts.shape = (40000, 784)
# yts.shape = (40000,)
# Xtr_let.shape = (124800, 784)
# ytr_let.shape = (124800,)
# Xts_let.shape = (20800, 784)
# yts_let.shape = (20800,)

# %% [markdown]
# You should see 240000 training samples and 40000 test samples for the digits and 124800 training samples and 20800 test samples for the letters.

# %% [markdown]
# Next, we'll recreate the `plt_digit` function from the demo.

# %%
def plt_digit(x,y=None):
    nrow = 28
    ncol = 28
    xsq = x.reshape((nrow,ncol))
    plt.imshow(xsq.T,  cmap='Greys_r')
    plt.xticks([])
    plt.yticks([])    
    if y != None:
        plt.title('%d' % y)

# %% [markdown]
# Plot 8 random samples from the training data.  You can use the `plt_digit` function above with `subplot` to create a nice display.  I suggest sizing your plots using the `plt.figure(figsize=(10,20))` command.

# %%
# TODO:  Plot 8 random samples from the training data of the digits
# Select random digits
nplt = 8
nsamp = Xtr_dig.shape[0]
Iperm = np.random.permutation(nsamp)

plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(Xtr_dig[ind,:], ytr_dig[ind]) 

plt.show()

# %% [markdown]
# Next, plot 8 random samples from the letters training data.  You should see that the labels go from 1 to 26, corresponding to `a` to `z`.  Upper and lower case letters belong to the same class.

# %%
# TODO:  Plot 8 random samples from the training data of the letters
nplt = 8
nsamp = Xtr_let.shape[0]
Iperm = np.random.permutation(nsamp)

plt.figure(figsize=(10,20))
for i in range(nplt):
    ind = Iperm[i]
    plt.subplot(1,nplt,i+1)
    plt_digit(Xtr_let[ind,:], ytr_let[ind]) 

plt.show()

# %% [markdown]
# ## Creating a Non-Digit Class
#
# SVM classifiers are very slow to train.  The training is particularly slow when there are a large number of classes.  To speed things up, we are going to put all of the letters in one class and merge that class with the digits data.
#
# Before we begin, we will remove all the samples corresponding to `i/I`, `l/L` and `o/O`, since otherwise these letters would get confused with the digits `0` and `1`.  Create arrays `Xtr_let_rem` and `ytr_let_rem` from the data `Xtr_let` and `ytr_let`, where the samples `i` with `ytr_let[i] == 9, 12, 15` are removed.   Create `Xts_let_rem` and `yts_let_rem` similarly.
#
# If you are clever, you can do this without a for-loop via python broadcasting and `np.all(..., axis=1)` command.  But, if you like, you can use a for-loop.

# %%
remove_list = np.array([9,12,15])

def remove_specific_labels_broadcast(X, y, remove_list):
    mask = np.all(y[:, np.newaxis] != remove_list, axis=1)
    return X[mask], y[mask]

# TODO:  Create arrays with labels 9, 12 and 15 removed
Xtr_let_rem, ytr_let_rem = remove_specific_labels_broadcast(Xtr_let, ytr_let, remove_list)
Xts_let_rem, yts_let_rem = remove_specific_labels_broadcast(Xts_let, yts_let, remove_list)

# %% [markdown]
# To speed things up even further, we will use only a small subset of the training and test data.  Of course, we will not get great results with this small dataset.  But we can still illustrate the basic concepts.
#
# Create training arrays `Xtr1_dig` and `ytr1_dig` by selecting 5000 random samples from `Xtr_dig` and `ytr_dig`.  Then create training arrays `Xtr1_let` and `ytr1_let` by selecting 1000 random samples from `Xtr_let_rem` and `ytr_let_rem`.  Similarly, create test arrays `Xts1_dig,Xts1_let,yts1_dig,yts1_let` with 5000 digits and 1000 letters.

# %%
# Number of training and test digits and letters
ntr_dig = 5000
ntr_let = 1000
nts_dig = 5000
nts_let = 1000

Ipermtr_dig = np.random.permutation(Xtr_dig.shape[0])
Ipermts_dig = np.random.permutation(Xts_dig.shape[0])
Ipermtr_let = np.random.permutation(Xtr_let.shape[0])
Ipermts_let = np.random.permutation(Xts_let.shape[0])

Xtr1_dig, ytr1_dig = Xtr_dig[Ipermtr_dig[:ntr_dig],:], ytr_dig[Ipermtr_dig[:ntr_dig]]
Xts1_dig, yts1_dig = Xts_dig[Ipermts_dig[ntr_dig:ntr_dig+nts_dig],:], yts_dig[Ipermts_dig[ntr_dig:ntr_dig+nts_dig]]
Xtr1_let, ytr1_let = Xtr_let[Ipermtr_let[:ntr_let],:], ytr_let[Ipermtr_let[:ntr_let]]
Xts1_let, yts1_let = Xts_let[Ipermts_let[ntr_let:ntr_let+nts_let],:], yts_let[Ipermts_let[ntr_let:ntr_let+nts_let]]

# %% [markdown]
# Now we will merge our digit and letter training arrays.
# * Create an array `Xtr` by stacking `Xtr1_dig`, `Xtr1_let`.  This should result in 6000 total samples.
# * Create a new label vector `ytr` where `ytr[i] = ytr1_dig[i]` for any digit sample and `ytr[i]=10` for any letter sample.  Thus, all the letters are lumped into the single class with label 10.
#
# Create test arrays `Xts` and `yts` similarly.
#
# You may wish to use the `np.hstack` and `np.vstack` methods.

# %%
# TODO:  Create combined letter and digit training and test data
Xtr = np.vstack((Xtr1_dig, Xtr1_let))
ytr = np.hstack((ytr1_dig, ytr1_let))
ytr[ytr1_dig.size:] = 10
Xts = np.vstack((Xts1_dig, Xts1_let))
yts = np.hstack((yts1_dig, yts1_let))
yts[yts1_dig.size:] = 10

# %% [markdown]
# The features above use pixel values from 0 to 255.  Let's rescale the pixels to the interval from -1.0 to 1.0.  This will yield slightly better performance.  We'll put the scaled data into arrays `Xtr1` and `Xts1`.  Note that the pixel data is 8-bit integer, so be careful not to use 8-bit multiplications like `2*Xtr` because they will overflow.

# %%
# TODO:  Rescale the data to the interval from -1.0 to 1.0
Xtr1 = Xtr/255.0 * 2 - 1
Xts1 = Xts/255.0 * 2 - 1

# %% [markdown]
# ## The SVM classifier
#
# Let's first create an SVM classifer with penalty `C=2.8` and an `rbf` kernel of width `gamma=.0073`. We will reexamine these choices later.

# %%
from sklearn import svm

# TODO:  Create a classifier: a support vector classifier
svc = svm.SVC(probability=False, kernel="rbf", C=2.8, gamma=.0073, verbose=1)

# %% [markdown]
# Now we fit the classifier using the scaled training data.  Although SVMs are slow to train, we have kept the training set small, so the fitting should take less than a minute.

# %%
# TODO:  Fit the classifier on the training data. 
svc.fit(Xtr1, ytr)
# Out:
# [LibSVM]*
# optimization finished, #iter = 371
# obj = -24.086112, rho = -0.629976
# nSV = 196, nBSV = 0
# *
# optimization finished, #iter = 719
# obj = -71.418717, rho = 0.135758
# nSV = 417, nBSV = 0
# *
# optimization finished, #iter = 643
# obj = -59.631722, rho = -0.043172
# nSV = 361, nBSV = 0
# *
# optimization finished, #iter = 675
# obj = -56.919607, rho = 0.066234
# nSV = 383, nBSV = 0
# *
# optimization finished, #iter = 743
# obj = -70.033705, rho = 0.101846
# nSV = 426, nBSV = 0
# *
# optimization finished, #iter = 731
# obj = -68.631856, rho = -0.081662
# nSV = 378, nBSV = 0
# *
# optimization finished, #iter = 548
# obj = -43.500708, rho = -0.220713
# nSV = 305, nBSV = 0
# *
# optimization finished, #iter = 671
# obj = -66.255050, rho = 0.184762
# nSV = 389, nBSV = 0
# *
# optimization finished, #iter = 574
# obj = -46.633828, rho = -0.149506
# nSV = 329, nBSV = 0
# .*
# optimization finished, #iter = 1635
# obj = -274.252916, rho = 0.746315
# nSV = 807, nBSV = 27
# *
# optimization finished, #iter = 433
# obj = -36.849153, rho = 0.780858
# nSV = 223, nBSV = 0
# *
# optimization finished, #iter = 419
# obj = -29.598127, rho = 0.612285
# nSV = 218, nBSV = 0
# *
# optimization finished, #iter = 468
# obj = -39.231490, rho = 0.798138
# nSV = 236, nBSV = 0
# *
# optimization finished, #iter = 439
# obj = -37.046902, rho = 0.735872
# nSV = 232, nBSV = 0
# *
# optimization finished, #iter = 411
# obj = -31.593336, rho = 0.595685
# nSV = 213, nBSV = 0
# *
# optimization finished, #iter = 469
# obj = -40.943668, rho = 0.558413
# nSV = 210, nBSV = 1
# *
# optimization finished, #iter = 402
# obj = -40.860196, rho = 0.846626
# nSV = 214, nBSV = 0
# *
# optimization finished, #iter = 401
# obj = -34.786074, rho = 0.548447
# nSV = 199, nBSV = 0
# *.*
# optimization finished, #iter = 1442
# obj = -442.051228, rho = 1.282600
# nSV = 478, nBSV = 98
# *
# optimization finished, #iter = 749
# obj = -78.320493, rho = -0.191780
# nSV = 432, nBSV = 0
# *
# optimization finished, #iter = 760
# obj = -70.755604, rho = -0.072615
# nSV = 450, nBSV = 0
# *
# optimization finished, #iter = 793
# obj = -74.286817, rho = -0.034755
# nSV = 458, nBSV = 0
# *
# optimization finished, #iter = 785
# obj = -69.989050, rho = -0.256042
# nSV = 441, nBSV = 0
# *
# optimization finished, #iter = 740
# obj = -64.948918, rho = -0.314309
# nSV = 401, nBSV = 0
# *
# optimization finished, #iter = 878
# obj = -92.068385, rho = 0.092644
# nSV = 501, nBSV = 0
# *
# optimization finished, #iter = 653
# obj = -54.911578, rho = -0.230867
# nSV = 375, nBSV = 0
# .*
# optimization finished, #iter = 1620
# obj = -226.490508, rho = 0.712546
# nSV = 878, nBSV = 3
# *
# optimization finished, #iter = 632
# obj = -51.649963, rho = 0.091262
# nSV = 376, nBSV = 0
# *
# optimization finished, #iter = 857
# obj = -99.245483, rho = 0.144025
# nSV = 477, nBSV = 0
# *
# optimization finished, #iter = 582
# obj = -48.447315, rho = -0.039497
# nSV = 329, nBSV = 0
# *
# optimization finished, #iter = 652
# obj = -55.201946, rho = -0.154879
# nSV = 359, nBSV = 0
# *
# optimization finished, #iter = 819
# obj = -100.948120, rho = 0.295844
# nSV = 449, nBSV = 0
# *
# optimization finished, #iter = 736
# obj = -64.685121, rho = -0.073630
# nSV = 406, nBSV = 0
# *.*
# optimization finished, #iter = 1124
# obj = -141.806707, rho = 0.752361
# nSV = 649, nBSV = 0
# *
# optimization finished, #iter = 791
# obj = -70.538070, rho = 0.048135
# nSV = 457, nBSV = 0
# *
# optimization finished, #iter = 688
# obj = -58.298522, rho = -0.144189
# nSV = 382, nBSV = 0
# *
# optimization finished, #iter = 664
# obj = -64.201070, rho = -0.274699
# nSV = 363, nBSV = 0
# *
# optimization finished, #iter = 835
# obj = -84.731528, rho = 0.164304
# nSV = 463, nBSV = 0
# *
# optimization finished, #iter = 960
# obj = -104.070132, rho = -0.263076
# nSV = 474, nBSV = 0
# .*
# optimization finished, #iter = 1709
# obj = -240.522146, rho = 0.647716
# nSV = 899, nBSV = 2
# *
# optimization finished, #iter = 747
# obj = -73.701884, rho = -0.200291
# nSV = 415, nBSV = 0
# *
# optimization finished, #iter = 676
# obj = -54.380743, rho = -0.318817
# nSV = 383, nBSV = 0
# *
# optimization finished, #iter = 898
# obj = -105.566698, rho = 0.089182
# nSV = 492, nBSV = 0
# *
# optimization finished, #iter = 689
# obj = -65.245059, rho = -0.272419
# nSV = 392, nBSV = 0
# .*
# optimization finished, #iter = 1777
# obj = -241.725284, rho = 0.662503
# nSV = 946, nBSV = 6
# *
# optimization finished, #iter = 507
# obj = -33.807502, rho = -0.119122
# nSV = 286, nBSV = 0
# *
# optimization finished, #iter = 709
# obj = -71.561702, rho = 0.287544
# nSV = 392, nBSV = 0
# *
# optimization finished, #iter = 550
# obj = -41.246557, rho = -0.076487
# nSV = 309, nBSV = 1
# *.*
# optimization finished, #iter = 1310
# obj = -156.617611, rho = 0.796684
# nSV = 688, nBSV = 0
# *
# optimization finished, #iter = 720
# obj = -65.504046, rho = 0.442283
# nSV = 390, nBSV = 0
# *
# optimization finished, #iter = 947
# obj = -110.596578, rho = 0.097261
# nSV = 429, nBSV = 2
# *.*
# optimization finished, #iter = 1082
# obj = -116.944854, rho = 0.862189
# nSV = 565, nBSV = 3
# *
# optimization finished, #iter = 929
# obj = -97.017386, rho = -0.417027
# nSV = 483, nBSV = 1
# .*
# optimization finished, #iter = 1673
# obj = -246.992612, rho = 0.701933
# nSV = 914, nBSV = 2
# *.*
# optimization finished, #iter = 1305
# obj = -170.874236, rho = 0.842283
# nSV = 670, nBSV = 6
# Total nSV = 4364
# SVC(C=2.8, gamma=0.0073, verbose=1)

# %% [markdown]
# Now let's compute and print the accuracy on the test data.  This too should take less than a minute.  You should get an accuracy of around 89%.

# %%
# TODO:  Measure error on the test data
yhat_ts = svc.predict(Xts1)
acc = np.mean(yhat_ts == yts)
print('Accuracy = {0:f}'.format(acc))
# Out:
# Accuracy = 0.895667

# %% [markdown]
# The accuracy is bit lower than what we would get with digits only.  This is because the "letters" class is extremely complex.
#
# To see this, print and then plot the row-normalized confusion matrix.  You should see that the error rate on the "letters" class is much higher than the others.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# TODO:  Print and plot the normalized confusion matrix
C = confusion_matrix(yts,yhat_ts,normalize='true')
disp = ConfusionMatrixDisplay(C)
disp.plot()
plt.show()

# %% [markdown]
# Print the following:
# * the fraction of digits that are mislabeled as letters
# * the fraction of letters that are mislabeled as digits

# %%
# TODO:  Print the above error rates
print('Fraction of Digits mislabeled as letters = ', np.mean(yhat_ts[:5000] == 10))
print('Fraction of Letters mislabeled as digits = ', np.mean(yhat_ts[5000:] != 10))
# Out:
# Fraction of Digits mislabeled as letters =  0.061
# Fraction of Letters mislabeled as digits =  0.23

# %% [markdown]
# ## Optimizing gamma and C via Cross-Validation
#
# Above, and in the demo, we used externally provided `gamma` and `C` values.  In general, these parameters should be carefully chosen.  We will now choose these parameters via cross validation using sklearn's `GridSearchCV` method.
#
# Ideally, we would try many more values for each of the parameters, but this would take a long time.  So, we will try only 3 values for each.  Still, this will take several minutes to complete.

# %% [markdown]
# The `GridSearchCV` method does a train-test split in addition to the parameter search.  In this case, we already have a train-test split, and so we will first combine the train and test data back into a single dataset to use with `GridSearchCV`.
#
# Create arrays `X` and `y` from `Xtr1`, `Xts1`, `ytr` and `yts`.  Use `np.vstack` and `np.hstack`.

# %%
# TODO:  Create combined trained and test data X and y.
X = np.vstack((Xtr1, Xts1))
y = np.hstack((ytr, yts))

# %% [markdown]
# Normally, `GridSearchCV` will do $K$-fold validation and automatically split the data into training and test in each fold.  But, in this case, we want it to use only one fold with a specific train-test split.  To do this, we can do the following:
# * Create a vector `test_fold` where `test_fold[i] = -1` for the samples `i` in the training data (which indicates that they should not be used as test data in any fold) and `test_fold[i] = 0` for the samples `i` in the test data (which indicates that they should be used as test data in fold 0).
# * Run `ps = sklearn.model_selection.PredefinedSplit(test_fold)` to create a predefined test-split object.

# %%
# TODO:  Create a pre-defined test split object 
import sklearn.model_selection
test_fold = np.zeros(X.shape[0])
test_fold[:Xtr1.shape[0]] = -1
ps = sklearn.model_selection.PredefinedSplit(test_fold)

# %% [markdown]
# Now we are ready to run `GridSearchCV` and call it's `fit` method. Call `GridSearchCV` using `cv=ps` to use our test-split object. Also, use `verbose=10` to have it show progress during fitting.

# %%
from sklearn.model_selection import GridSearchCV
# TODO:  Create a GridSearchCV classifier
C_test = [0.1, 1, 10]
gam_test = [0.001, 0.01, 0.1]
param_grid = {'C': C_test, 'gamma': gam_test}
clf = GridSearchCV(svc, param_grid, cv=ps, verbose=10)
clf.fit(X, y);
# Out:
# Fitting 1 folds for each of 9 candidates, totalling 9 fits
# [CV 1/1; 1/9] START C=0.1, gamma=0.001..........................................
# [LibSVM]*
# optimization finished, #iter = 137
# obj = -13.966555, rho = -0.598854
# nSV = 230, nBSV = 216
# *
# optimization finished, #iter = 272
# obj = -31.014664, rho = 0.104253
# nSV = 473, nBSV = 446
# *
# optimization finished, #iter = 245
# obj = -27.012319, rho = -0.115086
# nSV = 424, nBSV = 400
# *
# optimization finished, #iter = 215
# obj = -23.664214, rho = 0.104825
# nSV = 373, nBSV = 345
# *
# optimization finished, #iter = 295
# obj = -33.355632, rho = 0.225841
# nSV = 508, nBSV = 481
# *
# optimization finished, #iter = 290
# obj = -31.132130, rho = -0.154730
# nSV = 486, nBSV = 458
# *
# optimization finished, #iter = 203
# obj = -21.426767, rho = -0.176763
# nSV = 350, nBSV = 330
# *
# optimization finished, #iter = 236
# obj = -25.846101, rho = 0.170196
# nSV = 403, nBSV = 381
# *
# optimization finished, #iter = 216
# obj = -21.085139, rho = -0.149787
# nSV = 347, nBSV = 317
# *
# optimization finished, #iter = 443
# obj = -59.612531, rho = 0.976213
# nSV = 758, nBSV = 729
# *
# optimization finished, #iter = 216
# obj = -24.381700, rho = 1.053409
# nSV = 383, nBSV = 364
# *
# optimization finished, #iter = 180
# obj = -18.807939, rho = 0.608857
# nSV = 306, nBSV = 286
# *
# optimization finished, #iter = 217
# obj = -25.794110, rho = 0.936785
# nSV = 399, nBSV = 382
# *
# optimization finished, #iter = 213
# obj = -24.788065, rho = 1.032188
# nSV = 390, nBSV = 372
# *
# optimization finished, #iter = 190
# obj = -19.553797, rho = 0.510498
# nSV = 315, nBSV = 290
# *
# optimization finished, #iter = 232
# obj = -25.401627, rho = 0.638930
# nSV = 398, nBSV = 378
# *
# optimization finished, #iter = 216
# obj = -26.835390, rho = 0.995981
# nSV = 407, nBSV = 389
# *
# optimization finished, #iter = 201
# obj = -23.008946, rho = 0.560123
# nSV = 369, nBSV = 353
# *
# optimization finished, #iter = 392
# obj = -54.611935, rho = 1.850358
# nSV = 700, nBSV = 685
# *
# optimization finished, #iter = 277
# obj = -32.844432, rho = -0.200845
# nSV = 491, nBSV = 467
# *
# optimization finished, #iter = 257
# obj = -28.516547, rho = -0.112049
# nSV = 438, nBSV = 411
# *
# optimization finished, #iter = 293
# obj = -34.904146, rho = 0.059689
# nSV = 531, nBSV = 512
# *
# optimization finished, #iter = 296
# obj = -36.468852, rho = -0.390303
# nSV = 547, nBSV = 523
# *
# optimization finished, #iter = 316
# obj = -30.879248, rho = -0.353050
# nSV = 497, nBSV = 460
# *
# optimization finished, #iter = 322
# obj = -38.952612, rho = 0.034995
# nSV = 574, nBSV = 551
# *
# optimization finished, #iter = 236
# obj = -25.427113, rho = -0.191626
# nSV = 410, nBSV = 391
# *
# optimization finished, #iter = 494
# obj = -64.479765, rho = 0.920884
# nSV = 836, nBSV = 810
# *
# optimization finished, #iter = 231
# obj = -23.593727, rho = 0.134471
# nSV = 394, nBSV = 363
# *
# optimization finished, #iter = 309
# obj = -38.679173, rho = 0.208381
# nSV = 557, nBSV = 537
# *
# optimization finished, #iter = 222
# obj = -24.283656, rho = 0.003408
# nSV = 396, nBSV = 376
# *
# optimization finished, #iter = 285
# obj = -30.281064, rho = -0.016505
# nSV = 482, nBSV = 458
# *
# optimization finished, #iter = 310
# obj = -37.788673, rho = 0.301706
# nSV = 546, nBSV = 522
# *
# optimization finished, #iter = 304
# obj = -31.383333, rho = 0.092764
# nSV = 498, nBSV = 476
# *
# optimization finished, #iter = 399
# obj = -50.028611, rho = 1.055473
# nSV = 689, nBSV = 661
# *
# optimization finished, #iter = 303
# obj = -35.768598, rho = 0.177976
# nSV = 547, nBSV = 518
# *
# optimization finished, #iter = 242
# obj = -26.007734, rho = -0.069073
# nSV = 416, nBSV = 392
# *
# optimization finished, #iter = 273
# obj = -29.814242, rho = -0.275982
# nSV = 474, nBSV = 451
# *
# optimization finished, #iter = 291
# obj = -36.033592, rho = 0.210433
# nSV = 534, nBSV = 518
# *
# optimization finished, #iter = 381
# obj = -44.388747, rho = -0.205020
# nSV = 652, nBSV = 630
# *
# optimization finished, #iter = 519
# obj = -71.100037, rho = 1.209480
# nSV = 896, nBSV = 865
# *
# optimization finished, #iter = 286
# obj = -34.766557, rho = -0.369378
# nSV = 536, nBSV = 514
# *
# optimization finished, #iter = 266
# obj = -30.006737, rho = -0.446077
# nSV = 479, nBSV = 454
# *
# optimization finished, #iter = 347
# obj = -43.996161, rho = -0.093831
# nSV = 644, nBSV = 618
# *
# optimization finished, #iter = 312
# obj = -33.738438, rho = -0.391755
# nSV = 529, nBSV = 500
# *
# optimization finished, #iter = 531
# obj = -73.773842, rho = 1.092786
# nSV = 928, nBSV = 901
# *
# optimization finished, #iter = 174
# obj = -16.818541, rho = -0.051654
# nSV = 293, nBSV = 267
# *
# optimization finished, #iter = 266
# obj = -30.301522, rho = 0.329337
# nSV = 468, nBSV = 447
# *
# optimization finished, #iter = 176
# obj = -18.102330, rho = -0.020969
# nSV = 307, nBSV = 288
# *
# optimization finished, #iter = 426
# obj = -55.866701, rho = 1.207216
# nSV = 758, nBSV = 738
# *
# optimization finished, #iter = 285
# obj = -33.095470, rho = 0.492388
# nSV = 508, nBSV = 486
# *
# optimization finished, #iter = 372
# obj = -47.426690, rho = 0.244613
# nSV = 688, nBSV = 672
# *
# optimization finished, #iter = 387
# obj = -47.890572, rho = 1.157391
# nSV = 690, nBSV = 662
# *
# optimization finished, #iter = 378
# obj = -42.473782, rho = -0.419175
# nSV = 625, nBSV = 599
# *
# optimization finished, #iter = 502
# obj = -70.746937, rho = 0.980055
# nSV = 879, nBSV = 858
# *
# optimization finished, #iter = 433
# obj = -54.423991, rho = 1.169114
# nSV = 753, nBSV = 723
# Total nSV = 5323
# [CV 1/1; 1/9] END ...........C=0.1, gamma=0.001;, score=0.766 total time=  21.8s
# [CV 1/1; 2/9] START C=0.1, gamma=0.01...........................................
# [LibSVM]*
# optimization finished, #iter = 318
# obj = -17.351041, rho = -0.786823
# nSV = 377, nBSV = 220
# *
# optimization finished, #iter = 484
# obj = -52.126430, rho = 0.357604
# nSV = 815, nBSV = 728
# *
# optimization finished, #iter = 446
# obj = -46.951531, rho = 0.054813
# nSV = 758, nBSV = 669
# *
# optimization finished, #iter = 463
# obj = -45.510993, rho = 0.130673
# nSV = 751, nBSV = 639
# *
# optimization finished, #iter = 485
# obj = -51.500273, rho = 0.267778
# nSV = 820, nBSV = 726
# *
# optimization finished, #iter = 452
# obj = -47.513359, rho = -0.068090
# nSV = 756, nBSV = 668
# *
# optimization finished, #iter = 420
# obj = -38.555437, rho = -0.180724
# nSV = 670, nBSV = 558
# *
# optimization finished, #iter = 477
# obj = -48.932968, rho = 0.226051
# nSV = 786, nBSV = 678
# *
# optimization finished, #iter = 437
# obj = -40.403727, rho = -0.089576
# nSV = 693, nBSV = 584
# *
# optimization finished, #iter = 899
# obj = -69.114666, rho = 0.887848
# nSV = 1165, nBSV = 746
# *
# optimization finished, #iter = 384
# obj = -20.429600, rho = 0.912184
# nSV = 456, nBSV = 250
# *
# optimization finished, #iter = 343
# obj = -18.925617, rho = 0.832096
# nSV = 401, nBSV = 224
# *
# optimization finished, #iter = 364
# obj = -21.548709, rho = 0.896383
# nSV = 449, nBSV = 269
# *
# optimization finished, #iter = 400
# obj = -20.285939, rho = 0.890355
# nSV = 461, nBSV = 243
# *
# optimization finished, #iter = 333
# obj = -19.449267, rho = 0.801875
# nSV = 406, nBSV = 244
# *
# optimization finished, #iter = 331
# obj = -21.845603, rho = 0.770823
# nSV = 425, nBSV = 287
# *
# optimization finished, #iter = 365
# obj = -21.427317, rho = 0.923990
# nSV = 447, nBSV = 276
# *
# optimization finished, #iter = 328
# obj = -20.613237, rho = 0.796580
# nSV = 413, nBSV = 273
# *
# optimization finished, #iter = 423
# obj = -40.458710, rho = 1.073921
# nSV = 589, nBSV = 473
# *
# optimization finished, #iter = 470
# obj = -55.877042, rho = -0.356440
# nSV = 843, nBSV = 778
# *
# optimization finished, #iter = 459
# obj = -54.937227, rho = -0.222782
# nSV = 839, nBSV = 781
# *
# optimization finished, #iter = 490
# obj = -59.607493, rho = -0.082705
# nSV = 892, nBSV = 842
# *
# optimization finished, #iter = 479
# obj = -52.035151, rho = -0.447802
# nSV = 814, nBSV = 730
# *
# optimization finished, #iter = 504
# obj = -48.675506, rho = -0.529946
# nSV = 805, nBSV = 685
# *
# optimization finished, #iter = 476
# obj = -62.954705, rho = -0.128230
# nSV = 894, nBSV = 857
# *
# optimization finished, #iter = 486
# obj = -47.971543, rho = -0.430215
# nSV = 790, nBSV = 688
# *
# optimization finished, #iter = 926
# obj = -78.527359, rho = 0.898105
# nSV = 1174, nBSV = 710
# *
# optimization finished, #iter = 440
# obj = -47.942194, rho = 0.098864
# nSV = 770, nBSV = 692
# *
# optimization finished, #iter = 494
# obj = -57.338610, rho = 0.164698
# nSV = 850, nBSV = 771
# *
# optimization finished, #iter = 441
# obj = -44.629325, rho = -0.121121
# nSV = 726, nBSV = 635
# *
# optimization finished, #iter = 464
# obj = -44.452980, rho = -0.221702
# nSV = 731, nBSV = 632
# *
# optimization finished, #iter = 489
# obj = -57.625961, rho = 0.188929
# nSV = 848, nBSV = 767
# *
# optimization finished, #iter = 475
# obj = -48.034847, rho = -0.121207
# nSV = 776, nBSV = 679
# *
# optimization finished, #iter = 807
# obj = -66.670616, rho = 0.875016
# nSV = 1118, nBSV = 749
# *
# optimization finished, #iter = 489
# obj = -56.427816, rho = 0.130581
# nSV = 861, nBSV = 791
# *
# optimization finished, #iter = 461
# obj = -46.153585, rho = -0.209721
# nSV = 748, nBSV = 647
# *
# optimization finished, #iter = 461
# obj = -47.023741, rho = -0.387881
# nSV = 764, nBSV = 670
# *
# optimization finished, #iter = 482
# obj = -57.633700, rho = 0.089738
# nSV = 861, nBSV = 794
# *
# optimization finished, #iter = 509
# obj = -59.026132, rho = -0.297310
# nSV = 878, nBSV = 804
# *
# optimization finished, #iter = 914
# obj = -76.590310, rho = 0.925569
# nSV = 1200, nBSV = 774
# *
# optimization finished, #iter = 469
# obj = -51.207702, rho = -0.329629
# nSV = 809, nBSV = 722
# *
# optimization finished, #iter = 478
# obj = -45.229198, rho = -0.431354
# nSV = 764, nBSV = 640
# *
# optimization finished, #iter = 479
# obj = -62.876459, rho = -0.069230
# nSV = 896, nBSV = 852
# *
# optimization finished, #iter = 492
# obj = -50.179626, rho = -0.340449
# nSV = 822, nBSV = 707
# *.*
# optimization finished, #iter = 1002
# obj = -79.431261, rho = 0.915103
# nSV = 1244, nBSV = 742
# *
# optimization finished, #iter = 396
# obj = -36.325289, rho = -0.115568
# nSV = 640, nBSV = 538
# *
# optimization finished, #iter = 463
# obj = -50.276655, rho = 0.318330
# nSV = 793, nBSV = 699
# *
# optimization finished, #iter = 416
# obj = -38.810522, rho = -0.026624
# nSV = 671, nBSV = 566
# *
# optimization finished, #iter = 870
# obj = -63.798328, rho = 0.918917
# nSV = 1120, nBSV = 684
# *
# optimization finished, #iter = 485
# obj = -48.417193, rho = 0.458172
# nSV = 786, nBSV = 676
# *
# optimization finished, #iter = 478
# obj = -54.747523, rho = 0.180604
# nSV = 836, nBSV = 764
# *
# optimization finished, #iter = 864
# obj = -57.067928, rho = 0.908830
# nSV = 1070, nBSV = 652
# *
# optimization finished, #iter = 493
# obj = -56.439652, rho = -0.367683
# nSV = 859, nBSV = 780
# *
# optimization finished, #iter = 892
# obj = -78.186112, rho = 0.911438
# nSV = 1187, nBSV = 747
# *
# optimization finished, #iter = 879
# obj = -64.439401, rho = 0.906223
# nSV = 1141, nBSV = 730
# Total nSV = 5498
# [CV 1/1; 2/9] END ............C=0.1, gamma=0.01;, score=0.575 total time=  27.2s
# [CV 1/1; 3/9] START C=0.1, gamma=0.1............................................
# [LibSVM]*.*
# optimization finished, #iter = 1366
# obj = -90.781300, rho = -0.905392
# nSV = 1023, nBSV = 497
# *.*
# optimization finished, #iter = 1380
# obj = -88.616732, rho = -0.911484
# nSV = 991, nBSV = 465
# *.*
# optimization finished, #iter = 1336
# obj = -94.934829, rho = -0.905012
# nSV = 1025, nBSV = 499
# *.*
# optimization finished, #iter = 1402
# obj = -92.706958, rho = -0.907296
# nSV = 1013, nBSV = 487
# *.*
# optimization finished, #iter = 1330
# obj = -93.264541, rho = -0.906725
# nSV = 1016, nBSV = 490
# *.*
# optimization finished, #iter = 1420
# obj = -92.889943, rho = -0.907106
# nSV = 1014, nBSV = 488
# *
# optimization finished, #iter = 841
# obj = -99.945639, rho = 0.900581
# nSV = 1057, nBSV = 737
# *.*
# optimization finished, #iter = 1458
# obj = -89.733461, rho = -0.910342
# nSV = 997, nBSV = 471
# *.*
# optimization finished, #iter = 1330
# obj = -100.026177, rho = 0.903407
# nSV = 1072, nBSV = 526
# .*
# optimization finished, #iter = 1890
# obj = -101.171170, rho = 0.946941
# nSV = 1526, nBSV = 526
# *
# optimization finished, #iter = 519
# obj = -85.837739, rho = -0.657960
# nSV = 950, nBSV = 902
# *
# optimization finished, #iter = 751
# obj = -90.657068, rho = 0.900768
# nSV = 996, nBSV = 740
# *
# optimization finished, #iter = 510
# obj = -89.245639, rho = -0.525318
# nSV = 980, nBSV = 960
# *
# optimization finished, #iter = 501
# obj = -89.684485, rho = -0.495453
# nSV = 984, nBSV = 972
# *
# optimization finished, #iter = 510
# obj = -89.390003, rho = -0.516516
# nSV = 982, nBSV = 965
# *.*
# optimization finished, #iter = 1063
# obj = -90.793078, rho = 0.905853
# nSV = 1028, nBSV = 497
# *
# optimization finished, #iter = 514
# obj = -86.794539, rho = -0.630319
# nSV = 958, nBSV = 919
# *.*
# optimization finished, #iter = 1442
# obj = -90.864290, rho = 0.908732
# nSV = 1043, nBSV = 497
# .*
# optimization finished, #iter = 1940
# obj = -92.597533, rho = 0.952847
# nSV = 1497, nBSV = 534
# *.*
# optimization finished, #iter = 1245
# obj = -88.507997, rho = 0.906807
# nSV = 964, nBSV = 465
# *.*
# optimization finished, #iter = 1200
# obj = -88.454169, rho = 0.904492
# nSV = 952, nBSV = 465
# *.*
# optimization finished, #iter = 1240
# obj = -88.468177, rho = 0.905095
# nSV = 955, nBSV = 465
# *.*
# optimization finished, #iter = 1178
# obj = -88.456275, rho = 0.904582
# nSV = 953, nBSV = 465
# *.*
# optimization finished, #iter = 1004
# obj = -88.626451, rho = 0.911901
# nSV = 996, nBSV = 465
# *
# optimization finished, #iter = 930
# obj = -88.379297, rho = 0.901272
# nSV = 936, nBSV = 465
# .*
# optimization finished, #iter = 1632
# obj = -88.689401, rho = 0.914608
# nSV = 1011, nBSV = 465
# .*
# optimization finished, #iter = 1961
# obj = -89.584068, rho = 0.953092
# nSV = 1465, nBSV = 465
# *.*
# optimization finished, #iter = 1204
# obj = -92.587730, rho = -0.902398
# nSV = 986, nBSV = 487
# *.*
# optimization finished, #iter = 1057
# obj = -93.143808, rho = -0.901797
# nSV = 989, nBSV = 490
# *.*
# optimization finished, #iter = 1181
# obj = -92.770202, rho = -0.902198
# nSV = 987, nBSV = 488
# *.*
# optimization finished, #iter = 1116
# obj = -94.946023, rho = 0.905460
# nSV = 1030, nBSV = 499
# *.*
# optimization finished, #iter = 1248
# obj = -89.621925, rho = -0.905605
# nSV = 970, nBSV = 471
# *.*
# optimization finished, #iter = 1603
# obj = -95.018531, rho = 0.908365
# nSV = 1045, nBSV = 499
# .*
# optimization finished, #iter = 1406
# obj = -96.048770, rho = 0.949656
# nSV = 1499, nBSV = 499
# *
# optimization finished, #iter = 868
# obj = -92.544046, rho = 0.900772
# nSV = 977, nBSV = 593
# *
# optimization finished, #iter = 561
# obj = -92.530962, rho = 0.900614
# nSV = 975, nBSV = 900
# *.*
# optimization finished, #iter = 1461
# obj = -92.717621, rho = 0.907734
# nSV = 1018, nBSV = 487
# *.*
# optimization finished, #iter = 1017
# obj = -89.566693, rho = -0.903260
# nSV = 958, nBSV = 471
# *.*
# optimization finished, #iter = 1418
# obj = -92.786678, rho = 0.910569
# nSV = 1033, nBSV = 487
# .*
# optimization finished, #iter = 1948
# obj = -93.768005, rho = 0.950871
# nSV = 1487, nBSV = 487
# *
# optimization finished, #iter = 742
# obj = -92.726339, rho = -0.900767
# nSV = 978, nBSV = 722
# *.*
# optimization finished, #iter = 1386
# obj = -93.275338, rho = 0.907165
# nSV = 1021, nBSV = 490
# *.*
# optimization finished, #iter = 1296
# obj = -89.581094, rho = -0.903870
# nSV = 961, nBSV = 471
# *.*
# optimization finished, #iter = 1568
# obj = -93.345239, rho = 0.910018
# nSV = 1036, nBSV = 490
# .*
# optimization finished, #iter = 1836
# obj = -94.338685, rho = 0.950569
# nSV = 1490, nBSV = 490
# *.*
# optimization finished, #iter = 1417
# obj = -92.900642, rho = 0.907545
# nSV = 1019, nBSV = 488
# *.*
# optimization finished, #iter = 1110
# obj = -89.568822, rho = -0.903351
# nSV = 959, nBSV = 471
# *.*
# optimization finished, #iter = 1468
# obj = -92.970001, rho = 0.910386
# nSV = 1034, nBSV = 488
# .*
# optimization finished, #iter = 1952
# obj = -93.955348, rho = 0.950770
# nSV = 1488, nBSV = 488
# *.*
# optimization finished, #iter = 1324
# obj = -89.743437, rho = -0.910765
# nSV = 1002, nBSV = 471
# *.*
# optimization finished, #iter = 1194
# obj = -100.939783, rho = 0.902492
# nSV = 1077, nBSV = 531
# .*.*
# optimization finished, #iter = 2253
# obj = -102.106324, rho = 0.946431
# nSV = 1531, nBSV = 531
# *.*
# optimization finished, #iter = 1434
# obj = -89.808034, rho = 0.913508
# nSV = 1017, nBSV = 471
# .*.*
# optimization finished, #iter = 2150
# obj = -90.725923, rho = 0.952483
# nSV = 1471, nBSV = 471
# .*.*
# optimization finished, #iter = 2434
# obj = -104.958810, rho = 0.944918
# nSV = 1546, nBSV = 546
# Total nSV = 6000
# [CV 1/1; 3/9] END .............C=0.1, gamma=0.1;, score=0.167 total time=  33.9s
# [CV 1/1; 4/9] START C=1, gamma=0.001............................................
# [LibSVM]*
# optimization finished, #iter = 104
# obj = -36.284142, rho = -0.870200
# nSV = 74, nBSV = 42
# *
# optimization finished, #iter = 259
# obj = -91.724553, rho = -0.026328
# nSV = 184, nBSV = 116
# *
# optimization finished, #iter = 262
# obj = -72.343920, rho = -0.326636
# nSV = 154, nBSV = 90
# *
# optimization finished, #iter = 243
# obj = -70.539151, rho = 0.307675
# nSV = 147, nBSV = 83
# *
# optimization finished, #iter = 250
# obj = -103.684888, rho = 0.192887
# nSV = 194, nBSV = 135
# *
# optimization finished, #iter = 244
# obj = -85.435253, rho = -0.130527
# nSV = 168, nBSV = 105
# *
# optimization finished, #iter = 172
# obj = -51.471230, rho = -0.371046
# nSV = 114, nBSV = 66
# *
# optimization finished, #iter = 196
# obj = -78.841376, rho = 0.286477
# nSV = 152, nBSV = 98
# *
# optimization finished, #iter = 189
# obj = -53.402722, rho = -0.183662
# nSV = 112, nBSV = 65
# *
# optimization finished, #iter = 542
# obj = -341.355787, rho = 1.905953
# nSV = 476, nBSV = 385
# *
# optimization finished, #iter = 186
# obj = -71.381397, rho = 1.495821
# nSV = 135, nBSV = 91
# *
# optimization finished, #iter = 140
# obj = -49.764935, rho = 0.707076
# nSV = 99, nBSV = 60
# *
# optimization finished, #iter = 217
# obj = -74.193915, rho = 1.581767
# nSV = 143, nBSV = 97
# *
# optimization finished, #iter = 189
# obj = -75.669479, rho = 1.397378
# nSV = 140, nBSV = 97
# *
# optimization finished, #iter = 118
# obj = -56.585268, rho = 0.554310
# nSV = 100, nBSV = 70
# *
# optimization finished, #iter = 268
# obj = -67.317750, rho = 0.791135
# nSV = 136, nBSV = 86
# *
# optimization finished, #iter = 156
# obj = -87.306872, rho = 1.498499
# nSV = 153, nBSV = 118
# *
# optimization finished, #iter = 209
# obj = -58.570697, rho = 0.438453
# nSV = 118, nBSV = 73
# *
# optimization finished, #iter = 402
# obj = -329.409933, rho = 2.978322
# nSV = 412, nBSV = 364
# *
# optimization finished, #iter = 277
# obj = -103.120166, rho = -0.317231
# nSV = 191, nBSV = 129
# *
# optimization finished, #iter = 225
# obj = -95.082980, rho = 0.006259
# nSV = 172, nBSV = 116
# *
# optimization finished, #iter = 307
# obj = -104.791280, rho = 0.098489
# nSV = 207, nBSV = 128
# *
# optimization finished, #iter = 258
# obj = -111.040270, rho = -0.664650
# nSV = 211, nBSV = 147
# *
# optimization finished, #iter = 253
# obj = -80.949437, rho = -0.349162
# nSV = 168, nBSV = 107
# *
# optimization finished, #iter = 364
# obj = -125.555061, rho = -0.082150
# nSV = 241, nBSV = 157
# *
# optimization finished, #iter = 231
# obj = -62.297834, rho = -0.294896
# nSV = 136, nBSV = 76
# *
# optimization finished, #iter = 615
# obj = -321.816065, rho = 2.161456
# nSV = 486, nBSV = 361
# *
# optimization finished, #iter = 214
# obj = -58.668543, rho = 0.260522
# nSV = 130, nBSV = 65
# *
# optimization finished, #iter = 312
# obj = -142.100405, rho = 0.645804
# nSV = 247, nBSV = 175
# *
# optimization finished, #iter = 232
# obj = -52.084996, rho = -0.036579
# nSV = 124, nBSV = 63
# *
# optimization finished, #iter = 215
# obj = -81.326836, rho = -0.015560
# nSV = 160, nBSV = 107
# *
# optimization finished, #iter = 326
# obj = -135.401469, rho = 0.535854
# nSV = 237, nBSV = 167
# *
# optimization finished, #iter = 248
# obj = -85.629108, rho = 0.077356
# nSV = 171, nBSV = 107
# *
# optimization finished, #iter = 364
# obj = -224.156099, rho = 2.279219
# nSV = 339, nBSV = 272
# *
# optimization finished, #iter = 285
# obj = -106.819469, rho = 0.212442
# nSV = 203, nBSV = 135
# *
# optimization finished, #iter = 245
# obj = -73.555636, rho = -0.350112
# nSV = 151, nBSV = 85
# *
# optimization finished, #iter = 196
# obj = -82.578774, rho = -0.341807
# nSV = 156, nBSV = 107
# *
# optimization finished, #iter = 354
# obj = -116.020929, rho = 0.356578
# nSV = 219, nBSV = 135
# *
# optimization finished, #iter = 330
# obj = -146.013674, rho = -0.513303
# nSV = 251, nBSV = 187
# *
# optimization finished, #iter = 639
# obj = -402.346733, rho = 1.644417
# nSV = 563, nBSV = 460
# *
# optimization finished, #iter = 266
# obj = -104.569879, rho = -0.628073
# nSV = 191, nBSV = 130
# *
# optimization finished, #iter = 237
# obj = -76.272361, rho = -0.406237
# nSV = 159, nBSV = 97
# *
# optimization finished, #iter = 388
# obj = -152.226474, rho = -0.331593
# nSV = 273, nBSV = 188
# *
# optimization finished, #iter = 240
# obj = -93.178545, rho = -0.646274
# nSV = 178, nBSV = 116
# *
# optimization finished, #iter = 674
# obj = -391.082639, rho = 2.011527
# nSV = 572, nBSV = 456
# *
# optimization finished, #iter = 150
# obj = -32.579551, rho = -0.038809
# nSV = 85, nBSV = 39
# *
# optimization finished, #iter = 256
# obj = -88.085014, rho = 0.307725
# nSV = 171, nBSV = 113
# *
# optimization finished, #iter = 166
# obj = -37.492470, rho = -0.239875
# nSV = 95, nBSV = 46
# *
# optimization finished, #iter = 445
# obj = -252.253581, rho = 2.209001
# nSV = 383, nBSV = 294
# *
# optimization finished, #iter = 300
# obj = -89.900193, rho = 0.653052
# nSV = 190, nBSV = 114
# *
# optimization finished, #iter = 308
# obj = -166.940936, rho = 0.041707
# nSV = 271, nBSV = 218
# *
# optimization finished, #iter = 426
# obj = -180.238946, rho = 2.193247
# nSV = 311, nBSV = 218
# *
# optimization finished, #iter = 360
# obj = -138.046150, rho = -0.952797
# nSV = 255, nBSV = 179
# *
# optimization finished, #iter = 560
# obj = -407.642696, rho = 2.388498
# nSV = 564, nBSV = 480
# *
# optimization finished, #iter = 465
# obj = -243.036221, rho = 2.359536
# nSV = 381, nBSV = 285
# Total nSV = 3604
# [CV 1/1; 4/9] END .............C=1, gamma=0.001;, score=0.852 total time=  13.2s
# [CV 1/1; 5/9] START C=1, gamma=0.01.............................................
# [LibSVM]*
# optimization finished, #iter = 500
# obj = -29.863371, rho = -0.669970
# nSV = 285, nBSV = 9
# *
# optimization finished, #iter = 964
# obj = -98.312717, rho = 0.182795
# nSV = 586, nBSV = 13
# *
# optimization finished, #iter = 825
# obj = -83.878160, rho = -0.002216
# nSV = 503, nBSV = 7
# *
# optimization finished, #iter = 837
# obj = -80.804270, rho = 0.060514
# nSV = 512, nBSV = 9
# *
# optimization finished, #iter = 935
# obj = -95.523829, rho = 0.122804
# nSV = 564, nBSV = 11
# *
# optimization finished, #iter = 863
# obj = -89.918310, rho = -0.071568
# nSV = 499, nBSV = 13
# *
# optimization finished, #iter = 734
# obj = -62.870883, rho = -0.202261
# nSV = 436, nBSV = 3
# *
# optimization finished, #iter = 882
# obj = -92.558864, rho = 0.194222
# nSV = 537, nBSV = 16
# *
# optimization finished, #iter = 764
# obj = -67.512272, rho = -0.127190
# nSV = 464, nBSV = 6
# .*
# optimization finished, #iter = 1617
# obj = -223.932315, rho = 0.726293
# nSV = 1043, nBSV = 131
# *
# optimization finished, #iter = 563
# obj = -39.498979, rho = 0.823688
# nSV = 357, nBSV = 12
# *
# optimization finished, #iter = 502
# obj = -34.282036, rho = 0.695186
# nSV = 300, nBSV = 11
# *
# optimization finished, #iter = 583
# obj = -41.612937, rho = 0.818587
# nSV = 335, nBSV = 12
# *
# optimization finished, #iter = 566
# obj = -39.036330, rho = 0.784165
# nSV = 340, nBSV = 11
# *
# optimization finished, #iter = 537
# obj = -35.696419, rho = 0.666444
# nSV = 301, nBSV = 10
# *
# optimization finished, #iter = 541
# obj = -43.123409, rho = 0.624208
# nSV = 294, nBSV = 17
# *
# optimization finished, #iter = 515
# obj = -42.669457, rho = 0.849789
# nSV = 319, nBSV = 14
# *
# optimization finished, #iter = 502
# obj = -38.522900, rho = 0.637084
# nSV = 279, nBSV = 13
# *
# optimization finished, #iter = 964
# obj = -206.355969, rho = 1.097820
# nSV = 515, nBSV = 156
# *.*
# optimization finished, #iter = 971
# obj = -106.047827, rho = -0.188393
# nSV = 610, nBSV = 9
# *.*
# optimization finished, #iter = 1000
# obj = -100.736920, rho = -0.118243
# nSV = 623, nBSV = 10
# *.*
# optimization finished, #iter = 1027
# obj = -107.300116, rho = -0.060684
# nSV = 649, nBSV = 5
# *.*
# optimization finished, #iter = 955
# obj = -94.606919, rho = -0.268277
# nSV = 591, nBSV = 10
# *
# optimization finished, #iter = 949
# obj = -86.689677, rho = -0.364309
# nSV = 561, nBSV = 15
# *.*
# optimization finished, #iter = 1082
# obj = -126.920234, rho = 0.038783
# nSV = 675, nBSV = 9
# *
# optimization finished, #iter = 897
# obj = -80.352854, rho = -0.272616
# nSV = 555, nBSV = 6
# .*
# optimization finished, #iter = 1698
# obj = -242.214676, rho = 0.613282
# nSV = 1111, nBSV = 107
# *
# optimization finished, #iter = 849
# obj = -79.288129, rho = 0.056420
# nSV = 528, nBSV = 4
# *.*
# optimization finished, #iter = 1002
# obj = -122.421947, rho = 0.116459
# nSV = 618, nBSV = 25
# *
# optimization finished, #iter = 782
# obj = -73.413606, rho = -0.070903
# nSV = 486, nBSV = 1
# *
# optimization finished, #iter = 801
# obj = -74.894755, rho = -0.195954
# nSV = 483, nBSV = 5
# *
# optimization finished, #iter = 952
# obj = -127.206121, rho = 0.244954
# nSV = 595, nBSV = 23
# *
# optimization finished, #iter = 874
# obj = -84.930431, rho = -0.116827
# nSV = 529, nBSV = 13
# .*
# optimization finished, #iter = 1476
# obj = -166.068231, rho = 0.693059
# nSV = 953, nBSV = 56
# *.*
# optimization finished, #iter = 993
# obj = -100.253706, rho = 0.059206
# nSV = 613, nBSV = 3
# *
# optimization finished, #iter = 863
# obj = -81.485310, rho = -0.129947
# nSV = 530, nBSV = 7
# *
# optimization finished, #iter = 883
# obj = -85.090219, rho = -0.283936
# nSV = 518, nBSV = 18
# *.*
# optimization finished, #iter = 989
# obj = -113.872970, rho = 0.159777
# nSV = 623, nBSV = 15
# *.*
# optimization finished, #iter = 1107
# obj = -124.092689, rho = -0.225576
# nSV = 637, nBSV = 30
# .*
# optimization finished, #iter = 1797
# obj = -241.568556, rho = 0.697960
# nSV = 1129, nBSV = 118
# *
# optimization finished, #iter = 948
# obj = -96.694257, rho = -0.202053
# nSV = 560, nBSV = 14
# *
# optimization finished, #iter = 895
# obj = -75.937654, rho = -0.320843
# nSV = 529, nBSV = 7
# *.*
# optimization finished, #iter = 995
# obj = -135.951320, rho = 0.089919
# nSV = 630, nBSV = 17
# *
# optimization finished, #iter = 919
# obj = -88.435179, rho = -0.258934
# nSV = 565, nBSV = 8
# .*
# optimization finished, #iter = 1798
# obj = -240.808632, rho = 0.660872
# nSV = 1151, nBSV = 115
# *
# optimization finished, #iter = 715
# obj = -54.216702, rho = -0.120274
# nSV = 427, nBSV = 0
# *
# optimization finished, #iter = 890
# obj = -96.284985, rho = 0.285767
# nSV = 547, nBSV = 11
# *
# optimization finished, #iter = 751
# obj = -60.890687, rho = -0.059597
# nSV = 457, nBSV = 1
# .*
# optimization finished, #iter = 1524
# obj = -166.351633, rho = 0.759505
# nSV = 951, nBSV = 75
# *
# optimization finished, #iter = 887
# obj = -87.520675, rho = 0.419087
# nSV = 532, nBSV = 11
# *.*
# optimization finished, #iter = 1011
# obj = -118.299094, rho = 0.128535
# nSV = 562, nBSV = 46
# .*
# optimization finished, #iter = 1391
# obj = -128.242022, rho = 0.805109
# nSV = 871, nBSV = 48
# *.*
# optimization finished, #iter = 1018
# obj = -114.831294, rho = -0.381692
# nSV = 615, nBSV = 22
# .*
# optimization finished, #iter = 1720
# obj = -256.233444, rho = 0.629329
# nSV = 1133, nBSV = 137
# .*
# optimization finished, #iter = 1485
# obj = -166.157579, rho = 0.784778
# nSV = 967, nBSV = 79
# Total nSV = 4589
# [CV 1/1; 5/9] END ..............C=1, gamma=0.01;, score=0.876 total time=  23.7s
# [CV 1/1; 6/9] START C=1, gamma=0.1..............................................
# [LibSVM].*.*
# optimization finished, #iter = 2039
# obj = -354.887176, rho = -0.358301
# nSV = 998, nBSV = 162
# .*.*
# optimization finished, #iter = 2230
# obj = -491.674978, rho = -0.114835
# nSV = 991, nBSV = 465
# .*.*
# optimization finished, #iter = 2251
# obj = -511.486332, rho = -0.050114
# nSV = 1025, nBSV = 499
# .*.*
# optimization finished, #iter = 2151
# obj = -504.699389, rho = -0.072957
# nSV = 1013, nBSV = 487
# .*.*
# optimization finished, #iter = 2185
# obj = -506.456693, rho = -0.067246
# nSV = 1016, nBSV = 490
# .*.*
# optimization finished, #iter = 2253
# obj = -504.996855, rho = -0.071053
# nSV = 1014, nBSV = 488
# *.*
# optimization finished, #iter = 1708
# obj = -526.566789, rho = 0.003803
# nSV = 1057, nBSV = 469
# .*.*
# optimization finished, #iter = 2472
# obj = -495.349290, rho = -0.103414
# nSV = 997, nBSV = 471
# .*.*
# optimization finished, #iter = 2351
# obj = -534.620307, rho = 0.034066
# nSV = 1072, nBSV = 526
# ..*
# optimization finished, #iter = 2908
# obj = -649.118540, rho = 0.469390
# nSV = 1526, nBSV = 526
# .*
# optimization finished, #iter = 1737
# obj = -341.213273, rho = 0.294273
# nSV = 937, nBSV = 147
# .*
# optimization finished, #iter = 1919
# obj = -349.235057, rho = 0.331733
# nSV = 971, nBSV = 158
# .*
# optimization finished, #iter = 1848
# obj = -346.482141, rho = 0.318842
# nSV = 959, nBSV = 156
# .*
# optimization finished, #iter = 1870
# obj = -347.196103, rho = 0.322187
# nSV = 962, nBSV = 157
# .*
# optimization finished, #iter = 1855
# obj = -346.588526, rho = 0.319326
# nSV = 960, nBSV = 156
# .*.*
# optimization finished, #iter = 2068
# obj = -355.424923, rho = 0.360744
# nSV = 1003, nBSV = 162
# .*
# optimization finished, #iter = 1803
# obj = -342.703165, rho = 0.301212
# nSV = 943, nBSV = 150
# .*.*
# optimization finished, #iter = 2118
# obj = -358.734081, rho = 0.376461
# nSV = 1018, nBSV = 169
# ..*
# optimization finished, #iter = 2582
# obj = -443.309331, rho = 0.639391
# nSV = 1480, nBSV = 289
# .*.*
# optimization finished, #iter = 2094
# obj = -480.802725, rho = 0.068073
# nSV = 964, nBSV = 465
# .*.*
# optimization finished, #iter = 2009
# obj = -475.419354, rho = 0.044919
# nSV = 952, nBSV = 465
# .*.*
# optimization finished, #iter = 1995
# obj = -476.821347, rho = 0.050949
# nSV = 955, nBSV = 465
# .*
# optimization finished, #iter = 1711
# obj = -475.627722, rho = 0.045815
# nSV = 953, nBSV = 465
# .*
# optimization finished, #iter = 1753
# obj = -492.647091, rho = 0.119014
# nSV = 996, nBSV = 465
# .*.*
# optimization finished, #iter = 1874
# obj = -467.933034, rho = 0.012719
# nSV = 936, nBSV = 465
# ..*
# optimization finished, #iter = 2248
# obj = -498.940543, rho = 0.146085
# nSV = 1011, nBSV = 465
# ..*
# optimization finished, #iter = 2630
# obj = -588.408576, rho = 0.530893
# nSV = 1465, nBSV = 465
# .*
# optimization finished, #iter = 1934
# obj = -492.774003, rho = -0.023982
# nSV = 986, nBSV = 487
# .*
# optimization finished, #iter = 1957
# obj = -494.383928, rho = -0.017969
# nSV = 989, nBSV = 490
# .*.*
# optimization finished, #iter = 2009
# obj = -493.022556, rho = -0.022026
# nSV = 987, nBSV = 485
# .*
# optimization finished, #iter = 1962
# obj = -512.604645, rho = 0.054596
# nSV = 1030, nBSV = 499
# .*.*
# optimization finished, #iter = 2057
# obj = -484.194613, rho = -0.056048
# nSV = 970, nBSV = 471
# ..*
# optimization finished, #iter = 2171
# obj = -519.853228, rho = 0.083648
# nSV = 1045, nBSV = 499
# .*.*
# optimization finished, #iter = 2586
# obj = -622.882970, rho = 0.496592
# nSV = 1499, nBSV = 499
# .*
# optimization finished, #iter = 1702
# obj = -488.407040, rho = 0.006075
# nSV = 977, nBSV = 485
# *.*
# optimization finished, #iter = 1388
# obj = -487.097943, rho = 0.000779
# nSV = 975, nBSV = 428
# .*.*
# optimization finished, #iter = 2266
# obj = -505.764712, rho = 0.077331
# nSV = 1018, nBSV = 487
# .*
# optimization finished, #iter = 1830
# obj = -478.671419, rho = -0.032595
# nSV = 958, nBSV = 471
# .*.*
# optimization finished, #iter = 2185
# obj = -512.669757, rho = 0.105687
# nSV = 1033, nBSV = 487
# ..*
# optimization finished, #iter = 2910
# obj = -610.802907, rho = 0.508699
# nSV = 1487, nBSV = 487
# *.*
# optimization finished, #iter = 1613
# obj = -488.639206, rho = -0.004504
# nSV = 978, nBSV = 444
# .*.*
# optimization finished, #iter = 2171
# obj = -507.535008, rho = 0.071647
# nSV = 1021, nBSV = 490
# .*
# optimization finished, #iter = 1834
# obj = -480.109832, rho = -0.038703
# nSV = 961, nBSV = 471
# ..*
# optimization finished, #iter = 2249
# obj = -514.524461, rho = 0.100176
# nSV = 1036, nBSV = 490
# ..*
# optimization finished, #iter = 2702
# obj = -613.871666, rho = 0.505674
# nSV = 1490, nBSV = 490
# .*.*
# optimization finished, #iter = 2349
# obj = -506.066325, rho = 0.075437
# nSV = 1019, nBSV = 488
# .*
# optimization finished, #iter = 1889
# obj = -478.885244, rho = -0.033503
# nSV = 959, nBSV = 471
# .*.*
# optimization finished, #iter = 2241
# obj = -513.002722, rho = 0.103856
# nSV = 1034, nBSV = 488
# ..*
# optimization finished, #iter = 2989
# obj = -611.536633, rho = 0.507692
# nSV = 1488, nBSV = 488
# .*.*
# optimization finished, #iter = 2268
# obj = -496.345654, rho = -0.107645
# nSV = 1002, nBSV = 471
# .*
# optimization finished, #iter = 1943
# obj = -535.993674, rho = 0.026014
# nSV = 1077, nBSV = 496
# ..*.*
# optimization finished, #iter = 3480
# obj = -652.638542, rho = 0.464320
# nSV = 1531, nBSV = 531
# .*.*
# optimization finished, #iter = 2288
# obj = -502.806123, rho = 0.135073
# nSV = 1017, nBSV = 471
# ..*.*
# optimization finished, #iter = 3129
# obj = -594.595258, rho = 0.524841
# nSV = 1471, nBSV = 471
# ..*.*
# optimization finished, #iter = 3377
# obj = -667.886672, rho = 0.449183
# nSV = 1546, nBSV = 546
# Total nSV = 5983
# [CV 1/1; 6/9] END ...............C=1, gamma=0.1;, score=0.206 total time=  34.2s
# [CV 1/1; 7/9] START C=10, gamma=0.001...........................................
# [LibSVM]*
# optimization finished, #iter = 196
# obj = -69.032335, rho = -0.410502
# nSV = 54, nBSV = 2
# *
# optimization finished, #iter = 593
# obj = -160.635182, rho = 0.193025
# nSV = 115, nBSV = 2
# *
# optimization finished, #iter = 385
# obj = -135.012241, rho = -0.093384
# nSV = 89, nBSV = 2
# *
# optimization finished, #iter = 474
# obj = -131.100002, rho = 1.075840
# nSV = 109, nBSV = 2
# *
# optimization finished, #iter = 680
# obj = -186.511034, rho = 0.206190
# nSV = 139, nBSV = 3
# *
# optimization finished, #iter = 488
# obj = -155.228730, rho = -0.083946
# nSV = 100, nBSV = 3
# *
# optimization finished, #iter = 302
# obj = -77.797300, rho = -0.225429
# nSV = 79, nBSV = 1
# *
# optimization finished, #iter = 429
# obj = -160.969828, rho = 0.222614
# nSV = 105, nBSV = 2
# *
# optimization finished, #iter = 310
# obj = -94.345121, rho = -0.388222
# nSV = 79, nBSV = 1
# .*.*
# optimization finished, #iter = 2364
# obj = -1627.337286, rho = 3.961460
# nSV = 406, nBSV = 124
# *
# optimization finished, #iter = 354
# obj = -148.320139, rho = 0.619008
# nSV = 76, nBSV = 3
# *
# optimization finished, #iter = 247
# obj = -102.806018, rho = 0.453181
# nSV = 61, nBSV = 5
# *
# optimization finished, #iter = 445
# obj = -167.263444, rho = 1.480490
# nSV = 89, nBSV = 8
# *
# optimization finished, #iter = 435
# obj = -173.800412, rho = 0.960842
# nSV = 96, nBSV = 6
# *
# optimization finished, #iter = 203
# obj = -107.080540, rho = -0.041319
# nSV = 56, nBSV = 3
# *
# optimization finished, #iter = 315
# obj = -140.369364, rho = 0.498393
# nSV = 66, nBSV = 6
# *
# optimization finished, #iter = 394
# obj = -184.361570, rho = 1.342499
# nSV = 85, nBSV = 7
# *
# optimization finished, #iter = 310
# obj = -125.648044, rho = -0.317003
# nSV = 70, nBSV = 5
# *.*
# optimization finished, #iter = 1467
# obj = -2146.655729, rho = 3.046815
# nSV = 355, nBSV = 197
# *
# optimization finished, #iter = 579
# obj = -221.506821, rho = -0.513604
# nSV = 122, nBSV = 7
# *
# optimization finished, #iter = 560
# obj = -190.193843, rho = 0.743901
# nSV = 131, nBSV = 4
# *
# optimization finished, #iter = 604
# obj = -183.660754, rho = 0.284684
# nSV = 137, nBSV = 3
# *
# optimization finished, #iter = 577
# obj = -202.729293, rho = -1.055301
# nSV = 126, nBSV = 2
# *
# optimization finished, #iter = 451
# obj = -151.506975, rho = 0.224088
# nSV = 104, nBSV = 8
# *
# optimization finished, #iter = 745
# obj = -243.226281, rho = 0.127923
# nSV = 156, nBSV = 3
# *
# optimization finished, #iter = 379
# obj = -105.958980, rho = -0.302072
# nSV = 95, nBSV = 2
# .*.*
# optimization finished, #iter = 2065
# obj = -1222.203325, rho = 4.679781
# nSV = 380, nBSV = 82
# *
# optimization finished, #iter = 380
# obj = -97.362930, rho = 0.736994
# nSV = 97, nBSV = 1
# *.*
# optimization finished, #iter = 1006
# obj = -375.330337, rho = 0.991628
# nSV = 179, nBSV = 17
# *
# optimization finished, #iter = 287
# obj = -71.506435, rho = -0.148120
# nSV = 75, nBSV = 0
# *
# optimization finished, #iter = 443
# obj = -140.581876, rho = -0.123514
# nSV = 97, nBSV = 2
# *
# optimization finished, #iter = 744
# obj = -328.934452, rho = 0.129284
# nSV = 152, nBSV = 15
# *
# optimization finished, #iter = 565
# obj = -195.739512, rho = -0.053696
# nSV = 117, nBSV = 7
# *.*
# optimization finished, #iter = 1344
# obj = -679.285342, rho = 3.767329
# nSV = 252, nBSV = 36
# *
# optimization finished, #iter = 703
# obj = -183.865607, rho = -0.055028
# nSV = 141, nBSV = 2
# *
# optimization finished, #iter = 481
# obj = -153.197055, rho = -1.137714
# nSV = 119, nBSV = 4
# *
# optimization finished, #iter = 376
# obj = -150.360943, rho = -0.035906
# nSV = 93, nBSV = 2
# *
# optimization finished, #iter = 729
# obj = -248.664955, rho = -0.881276
# nSV = 161, nBSV = 8
# *
# optimization finished, #iter = 714
# obj = -387.043339, rho = -2.069941
# nSV = 149, nBSV = 27
# .*.*
# optimization finished, #iter = 2536
# obj = -1555.636387, rho = -0.240925
# nSV = 451, nBSV = 117
# *
# optimization finished, #iter = 521
# obj = -225.428178, rho = -1.069309
# nSV = 115, nBSV = 8
# *
# optimization finished, #iter = 450
# obj = -127.663922, rho = -0.189887
# nSV = 104, nBSV = 1
# *
# optimization finished, #iter = 911
# obj = -350.621260, rho = -1.110851
# nSV = 179, nBSV = 13
# *
# optimization finished, #iter = 431
# obj = -161.108765, rho = -1.094964
# nSV = 100, nBSV = 3
# .*.*
# optimization finished, #iter = 2600
# obj = -1490.737041, rho = 3.404527
# nSV = 441, nBSV = 96
# *
# optimization finished, #iter = 213
# obj = -37.551427, rho = 0.010697
# nSV = 64, nBSV = 0
# *
# optimization finished, #iter = 458
# obj = -178.295221, rho = 0.407622
# nSV = 107, nBSV = 6
# *
# optimization finished, #iter = 278
# obj = -58.725576, rho = -0.298288
# nSV = 73, nBSV = 1
# *.*
# optimization finished, #iter = 1403
# obj = -887.123637, rho = 4.439149
# nSV = 273, nBSV = 67
# *
# optimization finished, #iter = 500
# obj = -152.408368, rho = 0.744948
# nSV = 109, nBSV = 2
# *
# optimization finished, #iter = 896
# obj = -470.174090, rho = -1.405214
# nSV = 164, nBSV = 33
# *.*
# optimization finished, #iter = 1155
# obj = -510.274557, rho = 3.029570
# nSV = 210, nBSV = 29
# *
# optimization finished, #iter = 810
# obj = -318.752920, rho = -1.031390
# nSV = 156, nBSV = 9
# .*.*
# optimization finished, #iter = 2645
# obj = -1559.870854, rho = 6.440654
# nSV = 461, nBSV = 116
# *.*
# optimization finished, #iter = 1480
# obj = -930.998535, rho = 4.593301
# nSV = 277, nBSV = 64
# Total nSV = 3047
# [CV 1/1; 7/9] END ............C=10, gamma=0.001;, score=0.887 total time=  10.7s
# [CV 1/1; 8/9] START C=10, gamma=0.01............................................
# [LibSVM]*
# optimization finished, #iter = 495
# obj = -30.251341, rho = -0.654535
# nSV = 285, nBSV = 0
# *
# optimization finished, #iter = 983
# obj = -98.470953, rho = 0.181976
# nSV = 590, nBSV = 0
# *
# optimization finished, #iter = 830
# obj = -84.105632, rho = -0.000546
# nSV = 502, nBSV = 0
# *
# optimization finished, #iter = 855
# obj = -81.085405, rho = 0.058014
# nSV = 512, nBSV = 0
# *
# optimization finished, #iter = 943
# obj = -95.658432, rho = 0.121037
# nSV = 567, nBSV = 0
# *
# optimization finished, #iter = 877
# obj = -90.356826, rho = -0.068085
# nSV = 502, nBSV = 0
# *
# optimization finished, #iter = 738
# obj = -63.083578, rho = -0.200865
# nSV = 438, nBSV = 0
# *
# optimization finished, #iter = 870
# obj = -92.709187, rho = 0.191919
# nSV = 539, nBSV = 0
# *
# optimization finished, #iter = 773
# obj = -67.639216, rho = -0.124728
# nSV = 462, nBSV = 0
# .*
# optimization finished, #iter = 1956
# obj = -265.489543, rho = 0.696418
# nSV = 1089, nBSV = 0
# *
# optimization finished, #iter = 597
# obj = -40.476055, rho = 0.803831
# nSV = 365, nBSV = 0
# *
# optimization finished, #iter = 521
# obj = -34.892498, rho = 0.676572
# nSV = 304, nBSV = 0
# *
# optimization finished, #iter = 610
# obj = -42.980041, rho = 0.796778
# nSV = 347, nBSV = 0
# *
# optimization finished, #iter = 591
# obj = -40.369596, rho = 0.761444
# nSV = 345, nBSV = 0
# *
# optimization finished, #iter = 563
# obj = -36.379935, rho = 0.644749
# nSV = 305, nBSV = 0
# *
# optimization finished, #iter = 567
# obj = -44.755049, rho = 0.600162
# nSV = 297, nBSV = 0
# *
# optimization finished, #iter = 563
# obj = -43.572758, rho = 0.830921
# nSV = 322, nBSV = 0
# *
# optimization finished, #iter = 511
# obj = -39.339416, rho = 0.616955
# nSV = 277, nBSV = 0
# .*
# optimization finished, #iter = 1991
# obj = -846.709733, rho = 1.155581
# nSV = 536, nBSV = 46
# *.*
# optimization finished, #iter = 984
# obj = -106.613155, rho = -0.187020
# nSV = 612, nBSV = 0
# *.*
# optimization finished, #iter = 992
# obj = -100.998597, rho = -0.113430
# nSV = 626, nBSV = 0
# *.*
# optimization finished, #iter = 1022
# obj = -107.366609, rho = -0.061919
# nSV = 650, nBSV = 0
# *.*
# optimization finished, #iter = 959
# obj = -95.038680, rho = -0.264877
# nSV = 590, nBSV = 0
# *
# optimization finished, #iter = 957
# obj = -87.451068, rho = -0.363386
# nSV = 559, nBSV = 0
# *.*
# optimization finished, #iter = 1103
# obj = -127.107129, rho = 0.039473
# nSV = 675, nBSV = 0
# *
# optimization finished, #iter = 911
# obj = -80.701020, rho = -0.270915
# nSV = 557, nBSV = 0
# .*
# optimization finished, #iter = 1922
# obj = -252.426745, rho = 0.597969
# nSV = 1129, nBSV = 0
# *
# optimization finished, #iter = 841
# obj = -79.319878, rho = 0.055957
# nSV = 527, nBSV = 0
# *.*
# optimization finished, #iter = 1029
# obj = -123.827553, rho = 0.116524
# nSV = 623, nBSV = 0
# *
# optimization finished, #iter = 780
# obj = -73.424665, rho = -0.070016
# nSV = 486, nBSV = 0
# *
# optimization finished, #iter = 818
# obj = -74.924024, rho = -0.196070
# nSV = 483, nBSV = 0
# *.*
# optimization finished, #iter = 977
# obj = -127.992422, rho = 0.237738
# nSV = 596, nBSV = 0
# *
# optimization finished, #iter = 907
# obj = -85.728498, rho = -0.112150
# nSV = 532, nBSV = 0
# .*
# optimization finished, #iter = 1548
# obj = -168.850797, rho = 0.680637
# nSV = 970, nBSV = 0
# *.*
# optimization finished, #iter = 993
# obj = -100.274889, rho = 0.058320
# nSV = 613, nBSV = 0
# *
# optimization finished, #iter = 879
# obj = -81.702951, rho = -0.131900
# nSV = 533, nBSV = 0
# *
# optimization finished, #iter = 893
# obj = -85.322504, rho = -0.278332
# nSV = 517, nBSV = 0
# *.*
# optimization finished, #iter = 1016
# obj = -114.236266, rho = 0.156640
# nSV = 623, nBSV = 0
# *.*
# optimization finished, #iter = 1138
# obj = -125.540542, rho = -0.223121
# nSV = 641, nBSV = 0
# .*
# optimization finished, #iter = 1978
# obj = -253.045001, rho = 0.658260
# nSV = 1155, nBSV = 0
# *
# optimization finished, #iter = 936
# obj = -97.327036, rho = -0.198248
# nSV = 563, nBSV = 0
# *
# optimization finished, #iter = 902
# obj = -75.983298, rho = -0.318791
# nSV = 528, nBSV = 0
# *.*
# optimization finished, #iter = 1027
# obj = -136.427931, rho = 0.091207
# nSV = 634, nBSV = 0
# *
# optimization finished, #iter = 918
# obj = -88.640508, rho = -0.254407
# nSV = 564, nBSV = 0
# .*.*
# optimization finished, #iter = 2034
# obj = -256.294208, rho = 0.624242
# nSV = 1170, nBSV = 0
# *
# optimization finished, #iter = 707
# obj = -54.216702, rho = -0.120300
# nSV = 427, nBSV = 0
# *
# optimization finished, #iter = 913
# obj = -96.814743, rho = 0.279753
# nSV = 549, nBSV = 0
# *
# optimization finished, #iter = 752
# obj = -63.064485, rho = -0.061778
# nSV = 458, nBSV = 0
# .*
# optimization finished, #iter = 1627
# obj = -172.275640, rho = 0.742848
# nSV = 970, nBSV = 0
# *
# optimization finished, #iter = 916
# obj = -87.678006, rho = 0.416970
# nSV = 533, nBSV = 0
# *.*
# optimization finished, #iter = 1098
# obj = -122.054069, rho = 0.119132
# nSV = 561, nBSV = 0
# .*
# optimization finished, #iter = 1494
# obj = -133.675029, rho = 0.796201
# nSV = 881, nBSV = 0
# *.*
# optimization finished, #iter = 1085
# obj = -119.141608, rho = -0.373003
# nSV = 629, nBSV = 0
# .*
# optimization finished, #iter = 1957
# obj = -265.310079, rho = 0.597144
# nSV = 1155, nBSV = 0
# .*
# optimization finished, #iter = 1701
# obj = -180.063189, rho = 0.769713
# nSV = 1007, nBSV = 0
# Total nSV = 4723
# [CV 1/1; 8/9] END .............C=10, gamma=0.01;, score=0.879 total time=  24.6s
# [CV 1/1; 9/9] START C=10, gamma=0.1.............................................
# [LibSVM].*
# optimization finished, #iter = 1995
# obj = -358.954241, rho = -0.316714
# nSV = 998, nBSV = 0
# .*.*
# optimization finished, #iter = 2283
# obj = -493.298403, rho = -0.060967
# nSV = 991, nBSV = 0
# .*.*
# optimization finished, #iter = 2961
# obj = -511.806847, rho = -0.025735
# nSV = 1025, nBSV = 0
# ..*
# optimization finished, #iter = 2665
# obj = -505.367136, rho = -0.037993
# nSV = 1013, nBSV = 0
# .*.*
# optimization finished, #iter = 2566
# obj = -507.028565, rho = -0.034831
# nSV = 1016, nBSV = 0
# ..*
# optimization finished, #iter = 2886
# obj = -505.613416, rho = -0.037524
# nSV = 1014, nBSV = 0
# *.*
# optimization finished, #iter = 1860
# obj = -526.568281, rho = 0.002365
# nSV = 1057, nBSV = 0
# ..*
# optimization finished, #iter = 2540
# obj = -496.676649, rho = -0.054536
# nSV = 997, nBSV = 0
# .*.*
# optimization finished, #iter = 2740
# obj = -534.765572, rho = 0.017969
# nSV = 1072, nBSV = 0
# ...*.*
# optimization finished, #iter = 4438
# obj = -686.745737, rho = 0.307233
# nSV = 1526, nBSV = 0
# .*
# optimization finished, #iter = 1693
# obj = -343.706337, rho = 0.260769
# nSV = 937, nBSV = 0
# .*
# optimization finished, #iter = 1973
# obj = -352.590343, rho = 0.293371
# nSV = 971, nBSV = 0
# .*
# optimization finished, #iter = 1937
# obj = -349.522433, rho = 0.282117
# nSV = 959, nBSV = 0
# .*
# optimization finished, #iter = 1910
# obj = -350.316123, rho = 0.285041
# nSV = 962, nBSV = 0
# .*
# optimization finished, #iter = 1926
# obj = -349.640590, rho = 0.282551
# nSV = 960, nBSV = 0
# .*
# optimization finished, #iter = 1988
# obj = -359.563178, rho = 0.318863
# nSV = 1003, nBSV = 0
# .*
# optimization finished, #iter = 1519
# obj = -345.343915, rho = 0.266772
# nSV = 943, nBSV = 0
# .*.*
# optimization finished, #iter = 2051
# obj = -363.337404, rho = 0.332763
# nSV = 1018, nBSV = 0
# ..*
# optimization finished, #iter = 2961
# obj = -472.248463, rho = 0.574952
# nSV = 1485, nBSV = 0
# .*.*
# optimization finished, #iter = 2319
# obj = -481.358711, rho = 0.035288
# nSV = 964, nBSV = 0
# .*.*
# optimization finished, #iter = 2131
# obj = -475.658186, rho = 0.023027
# nSV = 952, nBSV = 0
# .*.*
# optimization finished, #iter = 2710
# obj = -477.129759, rho = 0.026192
# nSV = 955, nBSV = 0
# .*.*
# optimization finished, #iter = 2424
# obj = -475.876316, rho = 0.023496
# nSV = 953, nBSV = 0
# .*.*
# optimization finished, #iter = 2403
# obj = -494.394865, rho = 0.063323
# nSV = 996, nBSV = 0
# .*.*
# optimization finished, #iter = 1995
# obj = -467.951618, rho = 0.006452
# nSV = 936, nBSV = 0
# ..*.*
# optimization finished, #iter = 3003
# obj = -501.613018, rho = 0.078850
# nSV = 1011, nBSV = 0
# ...*.*
# optimization finished, #iter = 4328
# obj = -632.993153, rho = 0.361418
# nSV = 1465, nBSV = 0
# .*.*
# optimization finished, #iter = 2262
# obj = -492.843504, rho = -0.012270
# nSV = 986, nBSV = 0
# .*.*
# optimization finished, #iter = 2294
# obj = -494.423488, rho = -0.009104
# nSV = 989, nBSV = 0
# .*.*
# optimization finished, #iter = 2051
# obj = -493.077717, rho = -0.011801
# nSV = 987, nBSV = 0
# .*.*
# optimization finished, #iter = 2039
# obj = -512.985985, rho = 0.028098
# nSV = 1030, nBSV = 0
# .*.*
# optimization finished, #iter = 2449
# obj = -484.574851, rho = -0.028842
# nSV = 970, nBSV = 0
# ..*
# optimization finished, #iter = 2866
# obj = -520.762701, rho = 0.043683
# nSV = 1045, nBSV = 0
# ...*.*
# optimization finished, #iter = 4970
# obj = -663.795536, rho = 0.330343
# nSV = 1499, nBSV = 0
# *.*
# optimization finished, #iter = 1844
# obj = -488.411301, rho = 0.003167
# nSV = 977, nBSV = 0
# *.*
# optimization finished, #iter = 1018
# obj = -487.097943, rho = 0.000470
# nSV = 975, nBSV = 0
# ..*
# optimization finished, #iter = 2606
# obj = -506.516976, rho = 0.040354
# nSV = 1018, nBSV = 0
# .*.*
# optimization finished, #iter = 2305
# obj = -478.798450, rho = -0.016577
# nSV = 958, nBSV = 0
# .*.*
# optimization finished, #iter = 2780
# obj = -514.098372, rho = 0.055924
# nSV = 1033, nBSV = 0
# ...*.*
# optimization finished, #iter = 4631
# obj = -653.004086, rho = 0.341230
# nSV = 1487, nBSV = 0
# *.*
# optimization finished, #iter = 1642
# obj = -488.641284, rho = -0.002697
# nSV = 978, nBSV = 0
# ..*
# optimization finished, #iter = 2885
# obj = -508.185809, rho = 0.037193
# nSV = 1021, nBSV = 0
# .*.*
# optimization finished, #iter = 2296
# obj = -480.289473, rho = -0.019743
# nSV = 961, nBSV = 0
# ..*
# optimization finished, #iter = 2915
# obj = -515.816624, rho = 0.052766
# nSV = 1036, nBSV = 0
# ...*.*
# optimization finished, #iter = 4954
# obj = -655.780998, rho = 0.338429
# nSV = 1490, nBSV = 0
# ..*
# optimization finished, #iter = 2958
# obj = -506.764130, rho = 0.039886
# nSV = 1019, nBSV = 0
# .*.*
# optimization finished, #iter = 2316
# obj = -479.019506, rho = -0.017047
# nSV = 959, nBSV = 0
# ..*
# optimization finished, #iter = 2862
# obj = -514.356255, rho = 0.055457
# nSV = 1034, nBSV = 0
# ...*.*
# optimization finished, #iter = 4449
# obj = -653.415378, rho = 0.340816
# nSV = 1488, nBSV = 0
# .*.*
# optimization finished, #iter = 2314
# obj = -497.787113, rho = -0.056894
# nSV = 1002, nBSV = 0
# .*
# optimization finished, #iter = 1792
# obj = -536.068816, rho = 0.015606
# nSV = 1077, nBSV = 0
# ...*.*
# optimization finished, #iter = 4657
# obj = -688.849333, rho = 0.305080
# nSV = 1531, nBSV = 0
# ..*.*
# optimization finished, #iter = 3117
# obj = -505.109496, rho = 0.072435
# nSV = 1017, nBSV = 0
# ...*.*
# optimization finished, #iter = 4518
# obj = -638.566417, rho = 0.355796
# nSV = 1471, nBSV = 0
# ...*.*
# optimization finished, #iter = 4760
# obj = -702.941742, rho = 0.290858
# nSV = 1546, nBSV = 0
# Total nSV = 5988
# [CV 1/1; 9/9] END ..............C=10, gamma=0.1;, score=0.209 total time=  34.3s
# [LibSVM]*
# optimization finished, #iter = 300
# obj = -116.568181, rho = -0.363536
# nSV = 69, nBSV = 3
# *
# optimization finished, #iter = 867
# obj = -283.727554, rho = 0.615224
# nSV = 170, nBSV = 7
# *
# optimization finished, #iter = 716
# obj = -228.556919, rho = 0.177377
# nSV = 150, nBSV = 6
# *
# optimization finished, #iter = 819
# obj = -221.571430, rho = 1.392418
# nSV = 151, nBSV = 7
# *.*
# optimization finished, #iter = 1095
# obj = -374.318321, rho = 1.148101
# nSV = 199, nBSV = 13
# *
# optimization finished, #iter = 742
# obj = -290.948182, rho = 0.126965
# nSV = 150, nBSV = 16
# *
# optimization finished, #iter = 424
# obj = -126.019165, rho = -0.133720
# nSV = 98, nBSV = 2
# *
# optimization finished, #iter = 655
# obj = -278.975574, rho = -0.008502
# nSV = 146, nBSV = 10
# *
# optimization finished, #iter = 500
# obj = -171.409371, rho = -0.128826
# nSV = 109, nBSV = 4
# ..*..*
# optimization finished, #iter = 4256
# obj = -3221.825396, rho = 5.175960
# nSV = 703, nBSV = 259
# *
# optimization finished, #iter = 647
# obj = -230.701757, rho = 0.589478
# nSV = 116, nBSV = 8
# *
# optimization finished, #iter = 347
# obj = -150.335621, rho = 0.430199
# nSV = 82, nBSV = 5
# *
# optimization finished, #iter = 625
# obj = -315.329534, rho = 1.265766
# nSV = 134, nBSV = 22
# *
# optimization finished, #iter = 602
# obj = -269.351918, rho = 1.357249
# nSV = 130, nBSV = 13
# *
# optimization finished, #iter = 368
# obj = -148.407988, rho = -0.255366
# nSV = 81, nBSV = 5
# *
# optimization finished, #iter = 380
# obj = -188.250743, rho = 0.207854
# nSV = 86, nBSV = 10
# *
# optimization finished, #iter = 689
# obj = -324.835147, rho = 0.187450
# nSV = 135, nBSV = 17
# *
# optimization finished, #iter = 445
# obj = -176.645341, rho = 0.020374
# nSV = 93, nBSV = 9
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2808
# obj = -4007.786225, rho = 2.653325
# nSV = 626, nBSV = 375
# *.*
# optimization finished, #iter = 1044
# obj = -419.878734, rho = -0.191218
# nSV = 201, nBSV = 18
# *
# optimization finished, #iter = 960
# obj = -332.863869, rho = 0.571353
# nSV = 192, nBSV = 11
# *.*
# optimization finished, #iter = 1021
# obj = -308.465044, rho = 0.394783
# nSV = 201, nBSV = 7
# *
# optimization finished, #iter = 918
# obj = -296.757646, rho = -1.490840
# nSV = 181, nBSV = 4
# *
# optimization finished, #iter = 620
# obj = -244.123682, rho = -0.404031
# nSV = 132, nBSV = 12
# *.*
# optimization finished, #iter = 1243
# obj = -473.480099, rho = -0.978936
# nSV = 238, nBSV = 22
# *
# optimization finished, #iter = 548
# obj = -204.456158, rho = -0.276782
# nSV = 132, nBSV = 4
# ..*.*
# optimization finished, #iter = 3789
# obj = -2321.189939, rho = 6.127372
# nSV = 650, nBSV = 178
# *
# optimization finished, #iter = 523
# obj = -138.156359, rho = 0.624468
# nSV = 119, nBSV = 1
# *.*
# optimization finished, #iter = 1480
# obj = -662.957345, rho = 1.316421
# nSV = 263, nBSV = 38
# *
# optimization finished, #iter = 410
# obj = -111.594008, rho = -0.048401
# nSV = 100, nBSV = 1
# *
# optimization finished, #iter = 677
# obj = -244.469822, rho = -0.359738
# nSV = 135, nBSV = 10
# *.*
# optimization finished, #iter = 1259
# obj = -531.662408, rho = 0.052424
# nSV = 230, nBSV = 32
# *
# optimization finished, #iter = 803
# obj = -364.419651, rho = 0.610029
# nSV = 159, nBSV = 17
# .*.*
# optimization finished, #iter = 2257
# obj = -1399.953023, rho = 4.776277
# nSV = 425, nBSV = 103
# *.*
# optimization finished, #iter = 1106
# obj = -314.184940, rho = -0.156308
# nSV = 206, nBSV = 7
# *
# optimization finished, #iter = 835
# obj = -258.940356, rho = -1.307054
# nSV = 165, nBSV = 8
# *
# optimization finished, #iter = 739
# obj = -289.630728, rho = -0.769896
# nSV = 146, nBSV = 12
# *.*
# optimization finished, #iter = 1228
# obj = -430.966771, rho = -1.465997
# nSV = 226, nBSV = 20
# *.*
# optimization finished, #iter = 1263
# obj = -651.626861, rho = -2.140012
# nSV = 234, nBSV = 47
# ...*.*
# optimization finished, #iter = 4734
# obj = -2708.297897, rho = -0.607002
# nSV = 727, nBSV = 225
# *
# optimization finished, #iter = 901
# obj = -366.266131, rho = -2.063219
# nSV = 176, nBSV = 19
# *
# optimization finished, #iter = 651
# obj = -178.151359, rho = -0.327716
# nSV = 140, nBSV = 3
# *.*
# optimization finished, #iter = 1522
# obj = -564.488111, rho = -1.897803
# nSV = 268, nBSV = 27
# *
# optimization finished, #iter = 779
# obj = -301.132780, rho = -0.655442
# nSV = 154, nBSV = 13
# ..*..*
# optimization finished, #iter = 4471
# obj = -2795.491625, rho = 4.330699
# nSV = 740, nBSV = 216
# *
# optimization finished, #iter = 269
# obj = -45.580108, rho = 0.032087
# nSV = 75, nBSV = 0
# *
# optimization finished, #iter = 686
# obj = -251.126471, rho = 0.633325
# nSV = 148, nBSV = 9
# *
# optimization finished, #iter = 320
# obj = -87.807715, rho = 0.187537
# nSV = 86, nBSV = 1
# .*.*
# optimization finished, #iter = 2481
# obj = -1608.908473, rho = 6.408683
# nSV = 441, nBSV = 132
# *
# optimization finished, #iter = 742
# obj = -255.363629, rho = 0.473122
# nSV = 152, nBSV = 10
# .*
# optimization finished, #iter = 1715
# obj = -942.155730, rho = -1.722834
# nSV = 288, nBSV = 74
# .*
# optimization finished, #iter = 1697
# obj = -863.592270, rho = 3.839572
# nSV = 305, nBSV = 62
# *.*
# optimization finished, #iter = 1291
# obj = -520.887150, rho = 0.078558
# nSV = 224, nBSV = 22
# ...*.*
# optimization finished, #iter = 4889
# obj = -2758.726278, rho = 9.416938
# nSV = 790, nBSV = 227
# .*.*
# optimization finished, #iter = 2366
# obj = -1534.373281, rho = 4.562599
# nSV = 425, nBSV = 112
# Total nSV = 5233

# %% [markdown]
# Print the `best_score_` and `best_params_` attributes of the classifier to find the best score and parameters

# %%
# TODO:  Print the best parameter and score of the classifier
best_params = clf.best_params_
print('Best Score        =  {0:f}'.format(clf.best_score_))
print('Best C_test value = ', best_params['C'])
print('Best Gamma        = ', best_params['gamma'])
# Out:
# Best Score        =  0.887333
# Best C_test value =  10
# Best Gamma        =  0.001

# %% [markdown]
# Finally, print the CV test scores from `cv_results_['mean_test_score']`.

# %%
# TODO:  Print the mean test score for each parameter value.
print(clf.cv_results_['mean_test_score'])
# Out:
# [0.76633333 0.57533333 0.16666667 0.85233333 0.87633333 0.20566667
#  0.88733333 0.87933333 0.2095    ]

# %% [markdown]
# Note that the tuned performance may not be that great because the parameter grids were very coarse.  Using finer grids, you should be able to find better parameters and better performance, but at the expense of more computation.
